# %%
import diki049

# Uji coba fungsi
matriks_A = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matriks_B = [[9, 8, 7], [6, 5, 4], [3, 2, 1]]

print("Hasil Perkalian dari Modul:")
hasil = diki049.perkalian_matriks(matriks_A, matriks_B)

for baris in hasil:
    print(baris)
# Out:
# Hasil Perkalian dari Modul:
# [30, 24, 18]
# [84, 69, 54]
# [138, 114, 90]

# %%
import diki049

matriks_A = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

matriks_B = [
    [9, 8, 7],
    [6, 5, 4],
    [3, 2, 1]
]

print(" Hasil Penjumlahan dari Modul ")
hasil_tambah = diki049.penjumlahan_matriks(matriks_A, matriks_B)

for baris in hasil_tambah:
    print(baris)
# Out:
#  Hasil Penjumlahan dari Modul
# [10, 10, 10]
# [10, 10, 10]
# [10, 10, 10]
